# %% [markdown]
# #Project- Project- quick-view-of-price-surge-in-the-nigeria-economy<br>
# #Task2 - Preprocessing<br>
# #Team Members - Joseph Edet & Mohit Singh

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# https://docs.google.com/spreadsheets/d/1ZJTUIsqGBiS1XjZHCZ81wCq-P8BCZzi-NKsfoniPiYc/edit?gid=0#gid=0
#
# changing permissions
# https://docs.google.com/spreadsheets/d/1ZJTUIsqGBiS1XjZHCZ81wCq-P8BCZzi-NKsfoniPiYc/export?format=csv&gid=0

# %%
url = "https://docs.google.com/spreadsheets/d/1ZJTUIsqGBiS1XjZHCZ81wCq-P8BCZzi-NKsfoniPiYc/export?format=csv&gid=0"
pipe_original = pd.read_csv(url)
data = pipe_original.copy()
data.head()
# Out:
#    Year  Value(%)
# 0  1960     26.17
# 1  1961     25.49
# 2  1962     21.83
# 3  1963     22.32
# 4  1964     24.62

# %%
df = data.copy()
df.head()
# Out:
#    Year  Value(%)
# 0  1960     26.17
# 1  1961     25.49
# 2  1962     21.83
# 3  1963     22.32
# 4  1964     24.62

# %%
df.shape
# Out:
# (61, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Year      61 non-null     int64
#  1   Value(%)  61 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 1.1 KB

# %%
df.columns
# Out:
# Index(['Year', 'Value(%)'], dtype='object')

# %%
df[['Year','Value(%)']].nunique()
# Out:
# Year        61
# Value(%)    61
# dtype: int64

# %%
df = df.set_index('Year')
df.head()
# Out:
#       Value(%)
# Year
# 1960     26.17
# 1961     25.49
# 1962     21.83
# 1963     22.32
# 1964     24.62

# %%
# save dataset to csv file
df.to_csv('Trade Openness - IndexMundi.csv')
