# %% [markdown]
# #Project- Project- quick-view-of-price-surge-in-the-nigeria-economy<br>
# #Task2 - Preprocessing<br>
# #Team Members - Joseph Edet & Mohit Singh

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# https://docs.google.com/spreadsheets/d/1T9vE3oIDji5QFvONuWM3oKeZap2Whcl1ytbZFob0oIE/edit?gid=0#gid=0
#
# changing permissions
# https://docs.google.com/spreadsheets/d/1T9vE3oIDji5QFvONuWM3oKeZap2Whcl1ytbZFob0oIE//export?format=csv&gid=0

# %%
url = "https://docs.google.com/spreadsheets/d/1T9vE3oIDji5QFvONuWM3oKeZap2Whcl1ytbZFob0oIE/export?format=csv&gid=0"
pipe_original = pd.read_csv(url)
data = pipe_original.copy()
data.head()
#https://docs.google.com/spreadsheets/d/1T9vE3oIDji5QFvONuWM3oKeZap2Whcl1ytbZFob0oIE/edit?gid=0#gid=0
# Out:
#    Year  Trade Openness Index(%)
# 0  1960                 26.16651
# 1  1961                 25.48501
# 2  1962                 21.82950
# 3  1963                 22.31646
# 4  1964                 24.61532

# %%
df = data.copy()
df.head()
# Out:
#    Year  Trade Openness Index(%)
# 0  1960                 26.16651
# 1  1961                 25.48501
# 2  1962                 21.82950
# 3  1963                 22.31646
# 4  1964                 24.61532

# %%
df.shape
# Out:
# (64, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 2 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Year                     64 non-null     int64
#  1   Trade Openness Index(%)  62 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 1.1 KB

# %%
df.columns
# Out:
# Index(['Year', 'Trade Openness Index(%)'], dtype='object')

# %%
df[['Year','Trade Openness Index(%)']].nunique()
# Out:
# Year                       64
# Trade Openness Index(%)    62
# dtype: int64

# %%
df.iloc[62:]
# Out:
#     Year  Trade Openness Index(%)
# 62  2022                      NaN
# 63  2023                      NaN

# %%
df = df.iloc[:62]
df
# Out:
#     Year  Trade Openness Index(%)
# 0   1960                 26.16651
# 1   1961                 25.48501
# 2   1962                 21.82950
# 3   1963                 22.31646
# 4   1964                 24.61532
# ..   ...                      ...
# 57  2017                 26.34760
# 58  2018                 33.00783
# 59  2019                 34.02388
# 60  2020                 16.35219
# 61  2021                 22.57654
#
# [62 rows x 2 columns]

# %%
df = df.set_index('Year')
df.head()
# Out:
#       Trade Openness Index(%)
# Year
# 1960                 26.16651
# 1961                 25.48501
# 1962                 21.82950
# 1963                 22.31646
# 1964                 24.61532

# %%
# save dataset to csv file
df.to_csv('Trade Openness - Trade Economics.csv')
